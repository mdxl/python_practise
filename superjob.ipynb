# %%
import requests
from pprint import pprint
from bs4 import BeautifulSoup as bs


# https://russia.superjob.ru/vacancy/search/?keywords=python
# https://www.superjob.ru/vacancy/search/?keywords=Python&geo%5Bt%5D%5B0%5D=4
 
url = 'https://russia.superjob.ru/vacancy/search/ ? keywords=python'
 
#job = input('Введите желаемую должность ')
job = 'python'
main_url = 'https://russia.superjob.ru'
 
r_params = {'keywords': job,
           'page': '0',
           'geo':'%5Bt%5D%5B0%5D'}
 
r_headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.146 Safari/537.36'}
 
response = requests.get(main_url + '/vacancy/search', params = r_params, headers = r_headers)
soup = bs(response.text, 'html.parser')
cnt = 1
all_vacancies = []
while True:
    print(f'Страница {cnt} ')
    vacancy_list = soup.find_all ('div', {'class':'iJCa5 f-test-vacancy-item _1fma_ undefined _2nteL'})

    for vacancy in vacancy_list:
        vacancy_data = {}
        link = vacancy.find('a')
        vacancy_href = main_url + link.get('href')
        vacancy_name = link.getText()
        salary_data = vacancy.find('span', {'class': 'f-test-button-dalshe'})
        if salary_data is not None:
            vacancy_salary = salary_data.getText().replace('\xa0','')
            salary_text = ''.join(vacancy_salary.split()[:-1])
            vacancy_data['salary_cur'] = vacancy_salary.split()[-1].replace('.','')
            if salary_text.find('-') > -1:
                vacancy_data['salary_min'] = int(salary_text.split('-')[0])
                vacancy_data['salary_max'] = int(salary_text.split('-')[-1])
            elif salary_text.find('от') > -1:
                vacancy_data['salary_min'] = int(salary_text[2:])
                vacancy_data['salary_max'] = None
            elif salary_text.find('до') > -1:
                vacancy_data['salary_min'] = None
                vacancy_data['salary_max'] = int(salary_text[2:])
        else:
            vacancy_data['salary_min'] = None
            vacancy_data['salary_max'] = None
            vacancy_data['salary_cur'] = None
        vacancy_data['name'] = vacancy_name
        vacancy_data['href'] = vacancy_href
        #vacancy_data['salary'] = vacancy_salary
        all_vacancies.append(vacancy_data)
    pprint (all_vacancies [cnt*19])
    next_button = soup.find('a', {'class': 'f-test-link-Dalshe'})
    
    if next_button is None:
        break
    else:
        next_link = main_url + next_button.get('href')
        response = requests.get(next_link, headers = r_headers)
        soup = bs(response.text, 'html.parser')
        cnt +=1
        
    
    
    
    
    
pprint(all_vacancies)
# Out:
# Страница 1
# {'href': 'https://russia.superjob.ru/vakansii/it-specialist-35942231.html',
#  'name': 'IT-специалист',
#  'salary_cur': None,
#  'salary_max': None,
#  'salary_min': None}
# Страница 2
# {'href': 'https://russia.superjob.ru/vakansii/linux-administrator-35134882.html',
#  'name': 'Linux-администратор (devops)',
#  'salary_cur': None,
#  'salary_max': None,
#  'salary_min': None}
# Страница 3
# {'href': 'https://russia.superjob.ru/vakansii/programmist-1s-35340995.html',
#  'name': 'Программист 1С',
#  'salary_cur': None,
#  'salary_max': None,
#  'salary_min': None}
# Страница 4
# {'href': 'https://russia.superjob.ru/vakansii/inzhener-tehnicheskoj-podderzhki-35908230.html',
#  'name': 'Инженер технической поддержки',
#  'salary_cur': None,
#  'salary_max': None,
#  'salary_min': None}
# Страница 5
# {'href': 'https://russia.superjob.ru/vakansii/qa-engineer-35234900.html',
#  'name': 'QA Engineer',
#  'salary_cur': None,
#  'salary_max': None,
#  'salary_min': None}
# Страница 6
# {'href': 'https://russia.superjob.ru/vakansii/inzhener-po-soprovozhdeniyu-i-vnedreniyu-ppo-35800987.html',
#  'name': 'Инженер по сопровождению и внедрению ППО',
#  'salary_cur': None,
#  'salary_max': None,
#  'salary_min': None}
# [{'href': 'https://russia.superjob.ru/vakansii/backend-razrabotchik-35776255.html',
#   'name': 'Backend-разработчик (C++/Python)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/python-razrabotchik-35676216.html',
#   'name': 'Python-разработчик',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/senior-python-developer-v-proekt-clutch-35883206.html',
#   'name': 'Senior Python developer в проект Clutch',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/senior-qa-35839825.html',
#   'name': 'Senior QA (auto, Python)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/backend-python-razrabotchik-35351781.html',
#   'name': 'BackEnd Python-разработчик',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/razrabotchik-python-35618809.html',
#   'name': 'Разработчик Python (Middle, Full-Stack)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/veduschij-razrabotchik-programmnogo-obespecheniya-35899243.html',
#   'name': 'Ведущий разработчик программного обеспечения (senior Python '
#           'developer)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/senior-python-developer-35600756.html',
#   'name': 'Senior Python Developer',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/analitik-bazy-dannyh-35894795.html',
#   'name': 'Аналитик базы данных / Разработчик Python',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/backend-razrabotchik-python-35151272.html',
#   'name': 'Backend-разработчик Python',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/programmist-python-35817385.html',
#   'name': 'Программист Python',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/junior-razrabotchik-ml-35577688.html',
#   'name': 'Junior-разработчик ML (Python)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/inzhener-po-avtomatizirovannomu-testirovaniyu-35550301.html',
#   'name': 'Инженер по автоматизированному тестированию',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/nachalnik-otdela-sistemnogo-administrirovaniya-35184484.html',
#   'name': 'Начальник отдела системного администрирования',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/sistemnyj-administrator-33845400.html',
#   'name': 'Системный администратор, IT-специалист, программист',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/analitik-35784477.html',
#   'name': 'Аналитик',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/senior-data-analyst-35943229.html',
#   'name': 'Senior Data Analyst / Ведущий аналитик',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/produktovyj-analitik-33473129.html',
#   'name': 'Продуктовый аналитик',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/linux-administrator-35134882.html',
#   'name': 'Linux-администратор (devops)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/it-specialist-35942231.html',
#   'name': 'IT-специалист',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/backend-razrabotchik-35776255.html',
#   'name': 'Backend-разработчик (C++/Python)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/python-razrabotchik-35676216.html',
#   'name': 'Python-разработчик',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/senior-python-developer-v-proekt-clutch-35883206.html',
#   'name': 'Senior Python developer в проект Clutch',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/senior-qa-35839825.html',
#   'name': 'Senior QA (auto, Python)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/backend-python-razrabotchik-35351781.html',
#   'name': 'BackEnd Python-разработчик',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/razrabotchik-python-35618809.html',
#   'name': 'Разработчик Python (Middle, Full-Stack)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/veduschij-razrabotchik-programmnogo-obespecheniya-35899243.html',
#   'name': 'Ведущий разработчик программного обеспечения (senior Python '
#           'developer)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/senior-python-developer-35600756.html',
#   'name': 'Senior Python Developer',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/analitik-bazy-dannyh-35894795.html',
#   'name': 'Аналитик базы данных / Разработчик Python',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/backend-razrabotchik-python-35151272.html',
#   'name': 'Backend-разработчик Python',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/programmist-python-35817385.html',
#   'name': 'Программист Python',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/junior-razrabotchik-ml-35577688.html',
#   'name': 'Junior-разработчик ML (Python)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/inzhener-po-avtomatizirovannomu-testirovaniyu-35550301.html',
#   'name': 'Инженер по автоматизированному тестированию',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/nachalnik-otdela-sistemnogo-administrirovaniya-35184484.html',
#   'name': 'Начальник отдела системного администрирования',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/sistemnyj-administrator-33845400.html',
#   'name': 'Системный администратор, IT-специалист, программист',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/analitik-35784477.html',
#   'name': 'Аналитик',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/senior-data-analyst-35943229.html',
#   'name': 'Senior Data Analyst / Ведущий аналитик',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/produktovyj-analitik-33473129.html',
#   'name': 'Продуктовый аналитик',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/linux-administrator-35134882.html',
#   'name': 'Linux-администратор (devops)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/it-specialist-35942231.html',
#   'name': 'IT-специалист',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/devops-inzhener-35876478.html',
#   'name': 'DevOps инженер',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/data-scientist-35942366.html',
#   'name': 'Data Scientist / Специалист по машинному обучению',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/analitik-31183225.html',
#   'name': 'Аналитик',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/programmist-dev-ops-35548676.html',
#   'name': 'Программист DEV OPS (начальный опыт)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/web-programmist-33921626.html',
#   'name': 'Web-программист, Web-разработчик (удалённо)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/veduschij-sistemnyj-administrator-33495885.html',
#   'name': 'Ведущий системный администратор',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/veduschij-inzhener-programmist-35649581.html',
#   'name': 'Ведущий инженер-программист (машиностроительное производство)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/sistemnyj-administrator-linux-33832459.html',
#   'name': 'Системный администратор Linux',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/veduschij-analitik-klientskogo-servisa-35017990.html',
#   'name': 'Ведущий аналитик клиентского сервиса',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/seo-specialist-35551531.html',
#   'name': 'SEO-специалист',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/devops-inzhener-35776273.html',
#   'name': 'Devops-инженер',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/inzhener-34115922.html',
#   'name': 'Инженер (программирование)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/starshij-analitik-35708946.html',
#   'name': 'Старший аналитик (маркетинг)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/nachalnik-otdela-it-35300974.html',
#   'name': 'Начальник отдела ИТ',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/analitik-dannyh-35387855.html',
#   'name': 'Аналитик данных',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/junior-developer-35810889.html',
#   'name': 'Junior developer (PL/SQL)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/razrabotchik-proektirovschik-baz-dannyh-35676213.html',
#   'name': 'Разработчик-проектировщик баз данных (ведущий инженер-программист)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/programmist-1s-35340995.html',
#   'name': 'Программист 1С',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/glavnyj-specialist-otdela-sistem-monitoringa-i-nablyudeniya-35858870.html',
#   'name': 'Главный специалист отдела систем мониторинга и наблюдения',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/kontent-menedzher-35925866.html',
#   'name': 'Контент-менеджер',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/glavnyj-sistemnyj-analitik-35817869.html',
#   'name': 'Главный системный аналитик (Проект по разработке маркетплейса '
#           'Страховых и сервисных продуктов)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/veb-analitik-35776266.html',
#   'name': 'Веб-аналитик',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/glavnyj-specialist-otdela-sredstv-tehnicheskogo-kontrolya-35858806.html',
#   'name': 'Главный специалист отдела средств технического контроля',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/specialist-gruppy-soprovozhdeniya-programmnyh-izdelij-35674472.html',
#   'name': 'Специалист группы сопровождения программных изделий',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/inzhener-razrabotchik-35925146.html',
#   'name': 'Инженер-разработчик (электроника)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/inzhener-programmist-asutp-33562576.html',
#   'name': 'Инженер-программист АСУТП',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/veduschij-programmist-razrabotchik-fullstack-33885602.html',
#   'name': 'Ведущий программист-разработчик Fullstack',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/veduschij-inzhener-testirovschik-35658243.html',
#   'name': 'Ведущий инженер-тестировщик / QA',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/frontend-razrabotchik-35763068.html',
#   'name': 'Frontend разработчик / Веб-программист (Junior / Middle)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/backend-developer-35851341.html',
#   'name': 'Backend Developer',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/analitik-33865766.html',
#   'name': 'Аналитик',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/senior-backend-developer-34069324.html',
#   'name': 'Senior Backend Developer',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/qa-specialist-35756516.html',
#   'name': 'QA-специалист, QA-тестировщик (удаленно)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/full-stack-developer-35848433.html',
#   'name': 'Full stack developer / Фулстек-разработчик',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/programmist-pyrus-35374424.html',
#   'name': 'Программист pyrus',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/devops-inzhener-35839822.html',
#   'name': 'DevOps инженер / Linux инженер',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/inzhener-tehnicheskoj-podderzhki-35908230.html',
#   'name': 'Инженер технической поддержки',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/sistemnyj-administrator-linux-35740602.html',
#   'name': 'Системный администратор Linux',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/programmist-35810352.html',
#   'name': 'Программист',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/frontend-js-35351799.html',
#   'name': 'Frontend JS, Vue, Vuex, SPA-разработчик',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/veduschij-auditor-35613186.html',
#   'name': 'Ведущий аудитор',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/inzhener-analitik-sluzhby-tehnicheskoj-podderzhki-35658305.html',
#   'name': 'Инженер-аналитик службы технической поддержки',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/qa-engineer-35846358.html',
#   'name': 'QA-engineer, Автоматизатор / Специалист (QA-auto) удаленно',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/programmist-1c-35838516.html',
#   'name': 'Программист 1C',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/devops-inzhener-35729496.html',
#   'name': 'DevOps инженер',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/developer-35601260.html',
#   'name': 'Developer / Программист',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/programmist-issledovatel-35728667.html',
#   'name': 'Программист-исследователь',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/web-programmist-35827624.html',
#   'name': 'WEB программист',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/inzhener-33089687.html',
#   'name': 'Инженер, техник',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/starshij-sistemnyj-administrator-35594621.html',
#   'name': 'Старший системный администратор',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/inzhener-programmist-35817834.html',
#   'name': 'Инженер-программист',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/starshij-analitik-v-otdel-planirovaniya-35583105.html',
#   'name': 'Старший аналитик в отдел планирования',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/infrastrukturnyj-inzhener-35815072.html',
#   'name': 'Инфраструктурный инженер (DevOps)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/backend-razrabotchik-35882556.html',
#   'name': 'Backend-разработчик',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/internet-marketolog-35877418.html',
#   'name': 'Интернет-маркетолог',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/qa-engineer-35234900.html',
#   'name': 'QA Engineer',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/web-razrabotchik-35121873.html',
#   'name': 'Web-разработчик',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/servisnyj-inzhener-31940207.html',
#   'name': 'Сервисный инженер / Системный администратор',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/sistemnyj-administrator-35804388.html',
#   'name': 'Системный администратор, IT-специалист',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/bioinformatik-35001902.html',
#   'name': 'Биоинформатик',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/veduschij-inzhener-v-departament-obschih-prikladnyh-servisov-banka-35777295.html',
#   'name': 'Ведущий инженер в департамент общих прикладных сервисов Банка',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/razrabotchik-tehnicheskogo-zreniya-34233000.html',
#   'name': 'Разработчик технического зрения (Computer Vision / Image '
#           'Processing)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/devops-inzhener-35697784.html',
#   'name': 'DevOps инженер / SRE',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/sistemnyj-administrator-35554903.html',
#   'name': 'Системный администратор',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/senior-data-scientist-35871331.html',
#   'name': 'Senior Data Scientist (Remote option)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/programmist-35680668.html',
#   'name': 'Программист',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/bim-menedzher-35301972.html',
#   'name': 'BIM-менеджер',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/menedzher-po-prodazham-it-uslug-35300713.html',
#   'name': 'Менеджер по продажам IT-услуг',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/razrabotchik-voip-35866399.html',
#   'name': 'Разработчик VoIP',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/it-specialist-35550358.html',
#   'name': 'IT-специалист',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/inzhener-tehnicheskoj-podderzhki-35666479.html',
#   'name': 'Инженер технической поддержки (PL/SQL)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/glavnyj-inzhener-po-prikladnomu-soprovozhdeniyu-integracionnyh-reshenij-34076850.html',
#   'name': 'Главный инженер по прикладному сопровождению интеграционных решений',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/veduschij-inzhener-v-departament-upravleniya-dannymi-34483860.html',
#   'name': 'Ведущий инженер в департамент управления данными (SberData)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/starshij-inzhener-informacionnoj-bezopasnosti-35553677.html',
#   'name': 'Старший инженер информационной безопасности',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/inzhener-po-soprovozhdeniyu-i-vnedreniyu-ppo-35800987.html',
#   'name': 'Инженер по сопровождению и внедрению ППО',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/veduschij-specialist-po-podderzhke-slozhnyh-produktov-35715199.html',
#   'name': 'Ведущий специалист по поддержке сложных продуктов',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/programmist-35847760.html',
#   'name': 'Программист (junior)',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/starshij-specialist-tehnicheskoj-podderzhki-35847594.html',
#   'name': 'Старший специалист технической поддержки',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/middle-java-razrabotchik-35881706.html',
#   'name': 'Middle java разработчик',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None},
#  {'href': 'https://russia.superjob.ru/vakansii/ml-33788781.html',
#   'name': 'ML/NLP Architect / ML/NLP Архитектор',
#   'salary_cur': None,
#   'salary_max': None,
#   'salary_min': None}]

# %%
next_button = soup.find('a', {'class': 'f-test-link-Dalshe'})
next_link = main_url + next_button.get('href')
next_link
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-af86b51b4f01> in <module>
#       1 next_button = soup.find('a', {'class': 'f-test-link-Dalshe'})
# ----> 2 next_link = main_url + next_button.get('href')
#       3 next_link
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
next_button = soup.find('a', {'class': 'f-test-link-Dalshe'})
